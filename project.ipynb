# %% [markdown]
# # Dynamical Systems Theory in machine learning: Final Project
#
# Author: Fabian Kontor, 4013130

# %%
# run every python file in the folder "ng-rc-paper-code-master" and wait for it to finish before running the next one

import os

for file in os.listdir("ng-rc-paper-code-master"):
    if file.endswith(".py"):
        print("Running", file)
        # %run ng-rc-paper-code-master/$file
# Out:
# Running DoubleScrollNVAR-RK23.py
#
#  ridge regression parameter: 0.001
#
# mean, meanerr, train nrmse: 0.0012215437137279993 3.647299504100144e-05
# mean, meanerr, test nrmse: 0.0035778322194983544 0.0012215630175552322
#
# mean, meanerr, fp1 nL2 distance: 0.0021876830406739813 0.00026698090807080247
# mean, meanerr, fp2 nL2 distance: 0.0021876830406740754 0.00026698090807078767
# mean, meanerr, fp0 nL2 distance: 0.0 0.0
#
# mean, meanerr, fp1 [-0.0017095  -0.00012156 -0.00135829] [2.11828260e-04 1.83550519e-05 1.62647738e-04]
# mean, meanerr, fp2 [0.0017095  0.00012156 0.00135829] [2.11828260e-04 1.83550519e-05 1.62647738e-04]
# mean, meanerr, fp0 [0. 0. 0.] [0. 0. 0.]
#
# nL2 distance to mean, meanerr, fp1 0.0021868061356683905 0.0002676983496771583
# nL2 distance to mean, meanerr, fp2 0.002186806135668485 0.00026769834967714333
# nL2 distance to mean, meanerr, fp0 0.0 0.0
# Running LorenzConstLinQuadraticNVAR-Noise.py
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d
from numpy.random import default_rng

# %%
# Display all png files in the current folder with the name of the file below it
from IPython.display import Image
from IPython.core.display import HTML

for file in os.listdir("."):
    if file.endswith(".png"):
        print(file)
        display(Image(filename=file, width=500, unconfined=True))
        print()
# Out:
# infer-lorenz-wout.png
# infer-lorenz.png
# lorenz-rmap.png
# NRMSEvsTrainingPoints.png
# predict-dscroll.png
# predict-lorenz-noisy.png
# predict-lorenz-wout-zoom.png
# predict-lorenz-wout.png
# predict-lorenz.png
